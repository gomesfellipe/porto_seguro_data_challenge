# %%
pip install -U lightautoml
# Out:
# Collecting lightautoml
#   Downloading LightAutoML-0.2.16-py3-none-any.whl (262 kB)
#      |████████████████████████████████| 262 kB 862 kB/s
# Collecting efficientnet-pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.61.1)
# Requirement already satisfied: catboost in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.26)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.5)
# Collecting json2html
#   Downloading json2html-1.3.0.tar.gz (7.0 kB)
# Requirement already satisfied: cmaes in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from lightautoml) (5.4.1)
# Collecting poetry-core<2.0.0,>=1.0.0
#   Downloading poetry_core-1.0.4-py2.py3-none-any.whl (420 kB)
#      |████████████████████████████████| 420 kB 7.7 MB/s
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.18.2)
# Collecting importlib-metadata<2.0,>=1.0
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: optuna in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.8.0)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.23.2)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (from lightautoml) (3.2.4)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.5.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (3.0.1)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.1)
# Requirement already satisfied: gensim>=4 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.0.1)
# Collecting log-calls
#   Downloading log_calls-0.3.2.tar.gz (232 kB)
#      |████████████████████████████████| 232 kB 19.6 MB/s
# Requirement already satisfied: torch<1.9 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.7.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.19.5)
# Requirement already satisfied: holidays in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.5.2.54)
# Collecting lightgbm<3.0,>=2.3
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 20.0 MB/s
# Requirement already satisfied: transformers>=4 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.6.1)
# Requirement already satisfied: albumentations>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.0.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.6.3)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Collecting autowoe>=1.2
#   Downloading AutoWoE-1.2.5-py3-none-any.whl (204 kB)
#      |████████████████████████████████| 204 kB 39.8 MB/s
# Requirement already satisfied: pywavelets in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.1.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.0.1)
# Requirement already satisfied: pandas>=1 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.2.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from albumentations>=0.4.6->lightautoml) (4.5.2.54)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (6.2.4)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (2021.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (3.4.2)
# Collecting sphinx
#   Downloading Sphinx-4.1.2-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 54.8 MB/s
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (0.2.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.7/site-packages (from gensim>=4->lightautoml) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata<2.0,>=1.0->lightautoml) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1->lightautoml) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1->lightautoml) (1.15.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->lightautoml) (8.2.0)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->lightautoml) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->lightautoml) (2021.7.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx->lightautoml) (5.0.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.22->lightautoml) (2.1.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch<1.9->lightautoml) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch<1.9->lightautoml) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch<1.9->lightautoml) (0.6)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (3.0.12)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2.25.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (20.9)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2021.4.4)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.10.3)
# Requirement already satisfied: huggingface-hub==0.0.8 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.0.8)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.0.45)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (0.8.4)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (5.1.0)
# Requirement already satisfied: korean-lunar-calendar in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (0.2.1)
# Requirement already satisfied: convertdate>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.3.2)
# Requirement already satisfied: hijri-converter in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.1.3)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /opt/conda/lib/python3.7/site-packages (from convertdate>=2.3.0->holidays->lightautoml) (0.5.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from jinja2->lightautoml) (2.0.1)
# Requirement already satisfied: alembic in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.6.5)
# Requirement already satisfied: cliff in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (3.8.0)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (5.0.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.4.18)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.7/site-packages (from sqlalchemy>=1.1.0->optuna->lightautoml) (1.1.0)
# Requirement already satisfied: python-editor>=0.3 in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.0.4)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.1.4)
# Requirement already satisfied: cmd2>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (2.1.2)
# Requirement already satisfied: stevedore>=2.0.1 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (3.3.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (2.1.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (5.6.0)
# Requirement already satisfied: colorama>=0.3.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.4.4)
# Requirement already satisfied: attrs>=16.3.0 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (21.2.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (1.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from plotly->catboost->lightautoml) (7.0.0)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.10.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.13.1)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.1.1)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.10.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2021.5.30)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers>=4->lightautoml) (7.1.2)
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.9.1)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 7.0 MB/s
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (49.6.0.post20210108)
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.5
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 1.9 MB/s
# Requirement already satisfied: Pygments>=2.0 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.9.0)
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.1.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.4 MB/s
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 49.3 MB/s
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 7.7 MB/s
# Collecting imagesize
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Requirement already satisfied: docutils<0.18,>=0.14 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (0.17.1)
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.8 MB/s
# Building wheels for collected packages: efficientnet-pytorch, json2html, log-calls
# done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=6e0edbcf3dcbbcf9c60e8c276c00a8efc2d1a2a64256ba3d856afb7a1013d2d8
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# done
#   Created wheel for json2html: filename=json2html-1.3.0-py3-none-any.whl size=7595 sha256=0b92e81026e5274403fcb4bdc31d18566f0bc09e42546e80885cde492a332bb1
#   Stored in directory: /root/.cache/pip/wheels/e5/99/37/e1839a5ad733e0d6abb7e0419fd913e8926ddf96408239ce01
# done
#   Created wheel for log-calls: filename=log_calls-0.3.2-py3-none-any.whl size=51828 sha256=654e50eb7fd3cdf0d78837af401190bee4af2f400657e1687e9066abfa066785
#   Stored in directory: /root/.cache/pip/wheels/4c/4b/a5/a5643cfdcff002bbaf88cff0e52326db94182507613b53e971
# Successfully built efficientnet-pytorch json2html log-calls
# Installing collected packages: importlib-metadata, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, imagesize, alabaster, sphinx, lightgbm, poetry-core, log-calls, json2html, efficientnet-pytorch, autowoe, lightautoml
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.4.0
#     Uninstalling importlib-metadata-3.4.0:
#       Successfully uninstalled importlib-metadata-3.4.0
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 3.2.1
#     Uninstalling lightgbm-3.2.1:
#       Successfully uninstalled lightgbm-3.2.1
# Successfully installed alabaster-0.7.12 autowoe-1.2.5 efficientnet-pytorch-0.7.1 imagesize-1.2.0 importlib-metadata-1.7.0 json2html-1.3.0 lightautoml-0.2.16 lightgbm-2.3.1 log-calls-0.3.2 poetry-core-1.0.4 snowballstemmer-2.1.0 sphinx-4.1.2 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load dependencies

# %%
import pandas as pd
import numpy as np
import time
from tqdm import tqdm

import torch
from sklearn.metrics import f1_score, roc_auc_score, log_loss

# Imports from our package
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.dataset.roles import DatetimeRole
from lightautoml.tasks import Task

# Everything for graphs
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
train = pd.read_csv('../input/porto-seguro-data-challenge/train.csv', index_col='id')
train_id = train.index
train = train.reset_index(drop=True)
test = pd.read_csv('../input/porto-seguro-data-challenge/test.csv', index_col='id').reset_index(drop=True)
sample_submission = pd.read_csv('../input/porto-seguro-data-challenge/submission_sample.csv')
meta = pd.read_csv('../input/porto-seguro-data-challenge/metadata.csv')

# %%
# Add predictions from other models

train.loc[:,'cat_pseudo'] = pd.read_csv('../input/porto-seguro-catboost-pseudolabel/cat_pseudo_oof.csv').cat_pseudo_oof
test.loc[:,'cat_pseudo'] = pd.read_csv('../input/porto-seguro-catboost-pseudolabel/cat_pseudo_sub_probs.csv').predicted

train.loc[:,'cat_knn_shap'] = pd.read_csv('../input/porto-seguro-catboost-knn-shap/cat_oof.csv').cat_shap_oof
test.loc[:,'cat_knn_shap'] = pd.read_csv('../input/porto-seguro-catboost-knn-shap/cat_shap_sub_probs.csv').predicted

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

plt.figure(figsize = (5, 6))
ax1.scatter(train['cat_pseudo'], train['cat_knn_shap'])
ax1.plot([0, 1], [0, 1], '--r')
ax1.grid(True)
#ax1.title('Train data: cat_pseudo vs cat_knn_shap preds', fontsize = 17)
#ax1.xlabel('cat_pseudo', fontsize = 17)
#ax1.ylabel('cat_knn_shap', fontsize = 17)


ax2.scatter(test['cat_pseudo'], test['cat_knn_shap'])
ax2.plot([0, 1], [0, 1], '--r')
ax2.grid(True)
#ax2.title('Test data: cat_pseudo vs cat_knn_shap preds', fontsize = 17)
#ax2.xlabel('cat_pseudo', fontsize = 17)
#ax2.ylabel('cat_knn_shap', fontsize = 17)
plt.show()

# %%
# Create new features
for data in [train, test]:
    data['cat_pseudo_minus_cat_knn_shap'] = data['cat_pseudo'] - data['cat_knn_shap']
    data['cat_pseudo_mul_cat_knn_shap']   = data['cat_pseudo'] * data['cat_knn_shap']
    data['cat_pseudo_div_cat_knn_shap']   = data['cat_pseudo'] / data['cat_knn_shap']

# %%
def get_threshold(y_true, y_pred):
    # Moving threshold
    thresholds = np.arange(0.0, 1.0, 0.01)
    f1_scores = []
    for thresh in thresholds:
        f1_scores.append(
            f1_score(y_true, [1 if m>thresh else 0 for m in y_pred]))
    f1s = np.array(f1_scores)
    return thresholds[f1s.argmax()]
    
    
def custom_f1(y_true, y_pred):
     
    max_f1_threshold =  get_threshold(y_true, y_pred)

    y_pred = np.where(y_pred>max_f1_threshold, 1, 0)
    f1_after = f1_score(y_true, y_pred) 
    
    return f1_after

# %% [markdown]
# # LightAutoML

# %%
# %%time 

N_THREADS = 4 
N_FOLDS = 10
SEED = 5
TIMEOUT = 60 * 60 * 8
TARGET_NAME = 'y'

np.random.seed(SEED)
torch.set_num_threads(N_THREADS)

task = Task('binary', metric = roc_auc_score, greater_is_better=True)

roles = {
    'target': 'y'
}

automl = TabularUtilizedAutoML(task = task, 
                       timeout = TIMEOUT,
                       cpu_limit = N_THREADS,
                       general_params = {'use_algos': [['lgb', 'lgb_tuned', 'cb', 'cb_tunned'], 
                                                       ['linear_l2', 'lgb_tuned']]},
                       reader_params = {'n_jobs': N_THREADS})

y_oof = automl.fit_predict(train, roles = roles).data.ravel()
# Out:
# Current random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# Found reader_params in kwargs, need to combine
# Merged variant for reader_params = {'n_jobs': 4, 'random_state': 42}
# Found general_params in kwargs, need to combine
# Merged variant for general_params = {'use_algos': [['lgb', 'lgb_tuned', 'cb', 'cb_tunned'], ['linear_l2', 'lgb_tuned']], 'return_all_predictions': False}
# Start automl preset with listed constraints:
# - time: 28799.994587659836 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (14123, 74)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 28772.998673200607 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326862	valid's Opt metric: 0.876918
# [200]	valid's binary_logloss: 0.32776	valid's Opt metric: 0.877219
# Early stopping, best iteration is:
# [34]	valid's binary_logloss: 0.369587	valid's Opt metric: 0.879049
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.31727	valid's Opt metric: 0.889117
# [200]	valid's binary_logloss: 0.310695	valid's Opt metric: 0.889419
# [300]	valid's binary_logloss: 0.314327	valid's Opt metric: 0.888666
# Early stopping, best iteration is:
# [176]	valid's binary_logloss: 0.31046	valid's Opt metric: 0.889632
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.298281	valid's Opt metric: 0.903128
# [200]	valid's binary_logloss: 0.291171	valid's Opt metric: 0.902328
# Early stopping, best iteration is:
# [92]	valid's binary_logloss: 0.300594	valid's Opt metric: 0.903413
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.308567	valid's Opt metric: 0.894591
# [200]	valid's binary_logloss: 0.303733	valid's Opt metric: 0.894839
# Early stopping, best iteration is:
# [53]	valid's binary_logloss: 0.333426	valid's Opt metric: 0.896093
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.295213	valid's Opt metric: 0.906836
# [200]	valid's binary_logloss: 0.283548	valid's Opt metric: 0.908438
# [300]	valid's binary_logloss: 0.284623	valid's Opt metric: 0.908263
# [400]	valid's binary_logloss: 0.287534	valid's Opt metric: 0.907916
# Early stopping, best iteration is:
# [217]	valid's binary_logloss: 0.28292	valid's Opt metric: 0.909036
# Lvl_0_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 9668.245738885511 secs
# Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329804	valid's Opt metric: 0.870669
# [200]	valid's binary_logloss: 0.345939	valid's Opt metric: 0.873245
# [300]	valid's binary_logloss: 0.377434	valid's Opt metric: 0.873984
# Early stopping, best iteration is:
# [100]	valid's binary_logloss: 0.329804	valid's Opt metric: 0.870669
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327146	valid's Opt metric: 0.878292
# [200]	valid's binary_logloss: 0.326823	valid's Opt metric: 0.876194
# Early stopping, best iteration is:
# [7]	valid's binary_logloss: 0.455719	valid's Opt metric: 0.880174
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327864	valid's Opt metric: 0.876057
# [200]	valid's binary_logloss: 0.329579	valid's Opt metric: 0.875404
# Early stopping, best iteration is:
# [51]	valid's binary_logloss: 0.348429	valid's Opt metric: 0.877479
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327832	valid's Opt metric: 0.876086
# [200]	valid's binary_logloss: 0.331212	valid's Opt metric: 0.874918
# Early stopping, best iteration is:
# [24]	valid's binary_logloss: 0.39064	valid's Opt metric: 0.877155
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329362	valid's Opt metric: 0.871959
# [200]	valid's binary_logloss: 0.336098	valid's Opt metric: 0.873872
# [300]	valid's binary_logloss: 0.3563	valid's Opt metric: 0.874377
# Early stopping, best iteration is:
# [112]	valid's binary_logloss: 0.328573	valid's Opt metric: 0.87218
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325981	valid's Opt metric: 0.880454
# [200]	valid's binary_logloss: 0.323081	valid's Opt metric: 0.879349
# Early stopping, best iteration is:
# [83]	valid's binary_logloss: 0.329728	valid's Opt metric: 0.880847
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327112	valid's Opt metric: 0.87806
# [200]	valid's binary_logloss: 0.325952	valid's Opt metric: 0.878382
# Early stopping, best iteration is:
# [20]	valid's binary_logloss: 0.401301	valid's Opt metric: 0.878635
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328557	valid's Opt metric: 0.873203
# [200]	valid's binary_logloss: 0.336447	valid's Opt metric: 0.873175
# Early stopping, best iteration is:
# [30]	valid's binary_logloss: 0.3781	valid's Opt metric: 0.876618
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326689	valid's Opt metric: 0.878834
# [200]	valid's binary_logloss: 0.327177	valid's Opt metric: 0.876752
# Early stopping, best iteration is:
# [22]	valid's binary_logloss: 0.396353	valid's Opt metric: 0.879418
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328968	valid's Opt metric: 0.873077
# [200]	valid's binary_logloss: 0.336533	valid's Opt metric: 0.874108
# [300]	valid's binary_logloss: 0.354992	valid's Opt metric: 0.874538
# Early stopping, best iteration is:
# [119]	valid's binary_logloss: 0.328333	valid's Opt metric: 0.872972
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326397	valid's Opt metric: 0.880613
# [200]	valid's binary_logloss: 0.324047	valid's Opt metric: 0.878384
# Early stopping, best iteration is:
# [99]	valid's binary_logloss: 0.326555	valid's Opt metric: 0.880633
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325926	valid's Opt metric: 0.880987
# [200]	valid's binary_logloss: 0.322706	valid's Opt metric: 0.879448
# [300]	valid's binary_logloss: 0.32543	valid's Opt metric: 0.878169
# Early stopping, best iteration is:
# [107]	valid's binary_logloss: 0.324636	valid's Opt metric: 0.881133
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327727	valid's Opt metric: 0.875654
# [200]	valid's binary_logloss: 0.330233	valid's Opt metric: 0.874527
# [300]	valid's binary_logloss: 0.335577	valid's Opt metric: 0.87224
# Early stopping, best iteration is:
# [111]	valid's binary_logloss: 0.326435	valid's Opt metric: 0.876035
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.33072	valid's Opt metric: 0.871843
# [200]	valid's binary_logloss: 0.336111	valid's Opt metric: 0.872447
# Early stopping, best iteration is:
# [55]	valid's binary_logloss: 0.346626	valid's Opt metric: 0.873044
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326952	valid's Opt metric: 0.876862
# [200]	valid's binary_logloss: 0.327504	valid's Opt metric: 0.876084
# Early stopping, best iteration is:
# [11]	valid's binary_logloss: 0.434456	valid's Opt metric: 0.877792
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325769	valid's Opt metric: 0.880111
# [200]	valid's binary_logloss: 0.323087	valid's Opt metric: 0.879547
# Early stopping, best iteration is:
# [48]	valid's binary_logloss: 0.351041	valid's Opt metric: 0.880456
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327822	valid's Opt metric: 0.878874
# [200]	valid's binary_logloss: 0.323607	valid's Opt metric: 0.87847
# Early stopping, best iteration is:
# [94]	valid's binary_logloss: 0.328994	valid's Opt metric: 0.879071
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329162	valid's Opt metric: 0.873448
# [200]	valid's binary_logloss: 0.330641	valid's Opt metric: 0.873723
# Early stopping, best iteration is:
# [30]	valid's binary_logloss: 0.377674	valid's Opt metric: 0.874304
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325583	valid's Opt metric: 0.879625
# [200]	valid's binary_logloss: 0.323224	valid's Opt metric: 0.880105
# [300]	valid's binary_logloss: 0.325196	valid's Opt metric: 0.879522
# Early stopping, best iteration is:
# [128]	valid's binary_logloss: 0.322532	valid's Opt metric: 0.880588
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326199	valid's Opt metric: 0.87942
# [200]	valid's binary_logloss: 0.323716	valid's Opt metric: 0.87859
# Early stopping, best iteration is:
# [60]	valid's binary_logloss: 0.341956	valid's Opt metric: 0.879904
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.330264	valid's Opt metric: 0.872195
# [200]	valid's binary_logloss: 0.338814	valid's Opt metric: 0.871761
# Early stopping, best iteration is:
# [37]	valid's binary_logloss: 0.36631	valid's Opt metric: 0.874046
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326489	valid's Opt metric: 0.879373
# [200]	valid's binary_logloss: 0.324193	valid's Opt metric: 0.87847
# Early stopping, best iteration is:
# [99]	valid's binary_logloss: 0.32662	valid's Opt metric: 0.879464
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327105	valid's Opt metric: 0.879235
# [200]	valid's binary_logloss: 0.324326	valid's Opt metric: 0.878186
# [300]	valid's binary_logloss: 0.327921	valid's Opt metric: 0.876145
# Early stopping, best iteration is:
# [107]	valid's binary_logloss: 0.325944	valid's Opt metric: 0.879278
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328852	valid's Opt metric: 0.872798
# [200]	valid's binary_logloss: 0.330261	valid's Opt metric: 0.873479
# Early stopping, best iteration is:
# [21]	valid's binary_logloss: 0.399296	valid's Opt metric: 0.876573
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326916	valid's Opt metric: 0.876441
# [200]	valid's binary_logloss: 0.327874	valid's Opt metric: 0.875481
# Early stopping, best iteration is:
# [7]	valid's binary_logloss: 0.454366	valid's Opt metric: 0.879229
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327473	valid's Opt metric: 0.878651
# [200]	valid's binary_logloss: 0.325155	valid's Opt metric: 0.877458
# Early stopping, best iteration is:
# [28]	valid's binary_logloss: 0.383482	valid's Opt metric: 0.879625
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327031	valid's Opt metric: 0.877145
# [200]	valid's binary_logloss: 0.329592	valid's Opt metric: 0.874931
# Early stopping, best iteration is:
# [27]	valid's binary_logloss: 0.383289	valid's Opt metric: 0.879339
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325872	valid's Opt metric: 0.879663
# [200]	valid's binary_logloss: 0.325238	valid's Opt metric: 0.878386
# [300]	valid's binary_logloss: 0.327913	valid's Opt metric: 0.877524
# Early stopping, best iteration is:
# [102]	valid's binary_logloss: 0.325404	valid's Opt metric: 0.879861
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32628	valid's Opt metric: 0.877988
# [200]	valid's binary_logloss: 0.3261	valid's Opt metric: 0.877462
# Early stopping, best iteration is:
# [14]	valid's binary_logloss: 0.422757	valid's Opt metric: 0.880256
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.330228	valid's Opt metric: 0.871692
# [200]	valid's binary_logloss: 0.339917	valid's Opt metric: 0.87422
# [300]	valid's binary_logloss: 0.359795	valid's Opt metric: 0.874677
# Early stopping, best iteration is:
# [114]	valid's binary_logloss: 0.32959	valid's Opt metric: 0.872097
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.331369	valid's Opt metric: 0.870522
# [200]	valid's binary_logloss: 0.344022	valid's Opt metric: 0.871118
# Early stopping, best iteration is:
# [47]	valid's binary_logloss: 0.353093	valid's Opt metric: 0.871586
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326468	valid's Opt metric: 0.87868
# [200]	valid's binary_logloss: 0.324466	valid's Opt metric: 0.8784
# Early stopping, best iteration is:
# [14]	valid's binary_logloss: 0.421456	valid's Opt metric: 0.879844
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326328	valid's Opt metric: 0.878347
# [200]	valid's binary_logloss: 0.326189	valid's Opt metric: 0.876558
# Early stopping, best iteration is:
# [68]	valid's binary_logloss: 0.335392	valid's Opt metric: 0.879784
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329445	valid's Opt metric: 0.874608
# [200]	valid's binary_logloss: 0.332849	valid's Opt metric: 0.873518
# Early stopping, best iteration is:
# [74]	valid's binary_logloss: 0.33464	valid's Opt metric: 0.876401
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32606	valid's Opt metric: 0.879776
# [200]	valid's binary_logloss: 0.32571	valid's Opt metric: 0.877686
# Early stopping, best iteration is:
# [10]	valid's binary_logloss: 0.440064	valid's Opt metric: 0.88122
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326371	valid's Opt metric: 0.879146
# [200]	valid's binary_logloss: 0.325619	valid's Opt metric: 0.876557
# Early stopping, best iteration is:
# [33]	valid's binary_logloss: 0.37357	valid's Opt metric: 0.880422
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325439	valid's Opt metric: 0.879803
# [200]	valid's binary_logloss: 0.324547	valid's Opt metric: 0.879522
# Early stopping, best iteration is:
# [22]	valid's binary_logloss: 0.395565	valid's Opt metric: 0.880684
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326531	valid's Opt metric: 0.879315
# [200]	valid's binary_logloss: 0.325216	valid's Opt metric: 0.878007
# [300]	valid's binary_logloss: 0.328292	valid's Opt metric: 0.877097
# Early stopping, best iteration is:
# [120]	valid's binary_logloss: 0.323902	valid's Opt metric: 0.879521
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326768	valid's Opt metric: 0.877857
# [200]	valid's binary_logloss: 0.326121	valid's Opt metric: 0.877319
# Early stopping, best iteration is:
# [23]	valid's binary_logloss: 0.39399	valid's Opt metric: 0.87864
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32736	valid's Opt metric: 0.877248
# [200]	valid's binary_logloss: 0.32645	valid's Opt metric: 0.877002
# Early stopping, best iteration is:
# [83]	valid's binary_logloss: 0.331275	valid's Opt metric: 0.877609
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329959	valid's Opt metric: 0.872055
# [200]	valid's binary_logloss: 0.338294	valid's Opt metric: 0.87181
# Early stopping, best iteration is:
# [47]	valid's binary_logloss: 0.353854	valid's Opt metric: 0.872963
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326127	valid's Opt metric: 0.878681
# [200]	valid's binary_logloss: 0.32408	valid's Opt metric: 0.878921
# Early stopping, best iteration is:
# [57]	valid's binary_logloss: 0.343574	valid's Opt metric: 0.879094
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326225	valid's Opt metric: 0.878882
# [200]	valid's binary_logloss: 0.324432	valid's Opt metric: 0.878873
# Early stopping, best iteration is:
# [21]	valid's binary_logloss: 0.398564	valid's Opt metric: 0.879674
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326824	valid's Opt metric: 0.876148
# [200]	valid's binary_logloss: 0.328842	valid's Opt metric: 0.875076
# Early stopping, best iteration is:
# [43]	valid's binary_logloss: 0.356385	valid's Opt metric: 0.87616
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327297	valid's Opt metric: 0.87543
# [200]	valid's binary_logloss: 0.328437	valid's Opt metric: 0.874706
# Early stopping, best iteration is:
# [27]	valid's binary_logloss: 0.383091	valid's Opt metric: 0.878185
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327222	valid's Opt metric: 0.87758
# [200]	valid's binary_logloss: 0.327304	valid's Opt metric: 0.876729
# Early stopping, best iteration is:
# [17]	valid's binary_logloss: 0.411583	valid's Opt metric: 0.878265
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32697	valid's Opt metric: 0.878211
# [200]	valid's binary_logloss: 0.326193	valid's Opt metric: 0.876637
# Early stopping, best iteration is:
# [16]	valid's binary_logloss: 0.415857	valid's Opt metric: 0.878398
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326896	valid's Opt metric: 0.878982
# [200]	valid's binary_logloss: 0.324671	valid's Opt metric: 0.877512
# Early stopping, best iteration is:
# [28]	valid's binary_logloss: 0.384846	valid's Opt metric: 0.879434
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.324368	valid's Opt metric: 0.881347
# [200]	valid's binary_logloss: 0.321491	valid's Opt metric: 0.881758
# Early stopping, best iteration is:
# [88]	valid's binary_logloss: 0.32691	valid's Opt metric: 0.881802
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327892	valid's Opt metric: 0.873764
# [200]	valid's binary_logloss: 0.334656	valid's Opt metric: 0.874997
# [300]	valid's binary_logloss: 0.352018	valid's Opt metric: 0.875887
# Early stopping, best iteration is:
# [121]	valid's binary_logloss: 0.32701	valid's Opt metric: 0.873638
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327675	valid's Opt metric: 0.877364
# [200]	valid's binary_logloss: 0.327333	valid's Opt metric: 0.876996
# Early stopping, best iteration is:
# [73]	valid's binary_logloss: 0.334967	valid's Opt metric: 0.878206
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326255	valid's Opt metric: 0.879322
# [200]	valid's binary_logloss: 0.324171	valid's Opt metric: 0.878449
# Early stopping, best iteration is:
# [72]	valid's binary_logloss: 0.333938	valid's Opt metric: 0.880767
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326237	valid's Opt metric: 0.879805
# [200]	valid's binary_logloss: 0.324736	valid's Opt metric: 0.878761
# Early stopping, best iteration is:
# [33]	valid's binary_logloss: 0.371789	valid's Opt metric: 0.881323
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325858	valid's Opt metric: 0.880258
# [200]	valid's binary_logloss: 0.323278	valid's Opt metric: 0.879646
# [300]	valid's binary_logloss: 0.326508	valid's Opt metric: 0.877864
# Early stopping, best iteration is:
# [144]	valid's binary_logloss: 0.322086	valid's Opt metric: 0.88063
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326576	valid's Opt metric: 0.879325
# [200]	valid's binary_logloss: 0.323566	valid's Opt metric: 0.878711
# Early stopping, best iteration is:
# [33]	valid's binary_logloss: 0.372558	valid's Opt metric: 0.880208
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327072	valid's Opt metric: 0.878865
# [200]	valid's binary_logloss: 0.325699	valid's Opt metric: 0.877699
# Early stopping, best iteration is:
# [39]	valid's binary_logloss: 0.363061	valid's Opt metric: 0.880596
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326493	valid's Opt metric: 0.879129
# [200]	valid's binary_logloss: 0.324279	valid's Opt metric: 0.878031
# Early stopping, best iteration is:
# [86]	valid's binary_logloss: 0.329704	valid's Opt metric: 0.879576
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325948	valid's Opt metric: 0.879955
# [200]	valid's binary_logloss: 0.323537	valid's Opt metric: 0.879618
# [300]	valid's binary_logloss: 0.325565	valid's Opt metric: 0.879145
# Early stopping, best iteration is:
# [110]	valid's binary_logloss: 0.324424	valid's Opt metric: 0.880269
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327375	valid's Opt metric: 0.880175
# [200]	valid's binary_logloss: 0.322991	valid's Opt metric: 0.879594
# [300]	valid's binary_logloss: 0.325074	valid's Opt metric: 0.878481
# Early stopping, best iteration is:
# [121]	valid's binary_logloss: 0.32425	valid's Opt metric: 0.880264
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326408	valid's Opt metric: 0.878335
# [200]	valid's binary_logloss: 0.324836	valid's Opt metric: 0.878041
# Early stopping, best iteration is:
# [62]	valid's binary_logloss: 0.340093	valid's Opt metric: 0.87944
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328783	valid's Opt metric: 0.875532
# [200]	valid's binary_logloss: 0.331285	valid's Opt metric: 0.8742
# Early stopping, best iteration is:
# [49]	valid's binary_logloss: 0.351603	valid's Opt metric: 0.876216
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327115	valid's Opt metric: 0.877581
# [200]	valid's binary_logloss: 0.326373	valid's Opt metric: 0.877526
# Early stopping, best iteration is:
# [16]	valid's binary_logloss: 0.414599	valid's Opt metric: 0.879326
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325522	valid's Opt metric: 0.879849
# [200]	valid's binary_logloss: 0.324154	valid's Opt metric: 0.879463
# Early stopping, best iteration is:
# [52]	valid's binary_logloss: 0.346317	valid's Opt metric: 0.88033
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326323	valid's Opt metric: 0.879539
# [200]	valid's binary_logloss: 0.323363	valid's Opt metric: 0.878785
# Early stopping, best iteration is:
# [32]	valid's binary_logloss: 0.373761	valid's Opt metric: 0.880694
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326378	valid's Opt metric: 0.879759
# [200]	valid's binary_logloss: 0.32379	valid's Opt metric: 0.878956
# Early stopping, best iteration is:
# [69]	valid's binary_logloss: 0.335698	valid's Opt metric: 0.880431
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325678	valid's Opt metric: 0.880465
# [200]	valid's binary_logloss: 0.322051	valid's Opt metric: 0.880062
# [300]	valid's binary_logloss: 0.324739	valid's Opt metric: 0.878597
# Early stopping, best iteration is:
# [102]	valid's binary_logloss: 0.325193	valid's Opt metric: 0.88058
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327222	valid's Opt metric: 0.878177
# [200]	valid's binary_logloss: 0.326156	valid's Opt metric: 0.877764
# [300]	valid's binary_logloss: 0.33082	valid's Opt metric: 0.876992
# Early stopping, best iteration is:
# [168]	valid's binary_logloss: 0.324347	valid's Opt metric: 0.878394
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325446	valid's Opt metric: 0.880943
# [200]	valid's binary_logloss: 0.322461	valid's Opt metric: 0.88044
# Early stopping, best iteration is:
# [73]	valid's binary_logloss: 0.333332	valid's Opt metric: 0.881349
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325609	valid's Opt metric: 0.880435
# [200]	valid's binary_logloss: 0.324051	valid's Opt metric: 0.879292
# Early stopping, best iteration is:
# [72]	valid's binary_logloss: 0.333605	valid's Opt metric: 0.88105
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325561	valid's Opt metric: 0.880512
# [200]	valid's binary_logloss: 0.323013	valid's Opt metric: 0.879998
# Early stopping, best iteration is:
# [91]	valid's binary_logloss: 0.327098	valid's Opt metric: 0.880783
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326538	valid's Opt metric: 0.878838
# [200]	valid's binary_logloss: 0.325106	valid's Opt metric: 0.877975
# Early stopping, best iteration is:
# [74]	valid's binary_logloss: 0.33362	valid's Opt metric: 0.879383
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.324816	valid's Opt metric: 0.881128
# [200]	valid's binary_logloss: 0.322661	valid's Opt metric: 0.879998
# Early stopping, best iteration is:
# [94]	valid's binary_logloss: 0.325914	valid's Opt metric: 0.881288
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325469	valid's Opt metric: 0.87955
# [200]	valid's binary_logloss: 0.323061	valid's Opt metric: 0.879287
# Early stopping, best iteration is:
# [50]	valid's binary_logloss: 0.348928	valid's Opt metric: 0.881081
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.324877	valid's Opt metric: 0.880738
# [200]	valid's binary_logloss: 0.321459	valid's Opt metric: 0.880591
# Early stopping, best iteration is:
# [33]	valid's binary_logloss: 0.371363	valid's Opt metric: 0.881617
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325232	valid's Opt metric: 0.880377
# [200]	valid's binary_logloss: 0.322089	valid's Opt metric: 0.880291
# Early stopping, best iteration is:
# [30]	valid's binary_logloss: 0.377416	valid's Opt metric: 0.88102
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326033	valid's Opt metric: 0.880005
# [200]	valid's binary_logloss: 0.322579	valid's Opt metric: 0.87997
# [300]	valid's binary_logloss: 0.323393	valid's Opt metric: 0.879994
# Early stopping, best iteration is:
# [170]	valid's binary_logloss: 0.322059	valid's Opt metric: 0.880309
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326221	valid's Opt metric: 0.879349
# [200]	valid's binary_logloss: 0.324163	valid's Opt metric: 0.878618
# [300]	valid's binary_logloss: 0.326674	valid's Opt metric: 0.878395
# Early stopping, best iteration is:
# [106]	valid's binary_logloss: 0.325245	valid's Opt metric: 0.879538
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326876	valid's Opt metric: 0.878667
# [200]	valid's binary_logloss: 0.325566	valid's Opt metric: 0.878017
# Early stopping, best iteration is:
# [31]	valid's binary_logloss: 0.374874	valid's Opt metric: 0.879561
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326452	valid's Opt metric: 0.879066
# [200]	valid's binary_logloss: 0.324636	valid's Opt metric: 0.877965
# Early stopping, best iteration is:
# [59]	valid's binary_logloss: 0.342595	valid's Opt metric: 0.879547
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329737	valid's Opt metric: 0.871202
# [200]	valid's binary_logloss: 0.336843	valid's Opt metric: 0.871569
# [300]	valid's binary_logloss: 0.353377	valid's Opt metric: 0.872613
# Early stopping, best iteration is:
# [125]	valid's binary_logloss: 0.328886	valid's Opt metric: 0.8715
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325641	valid's Opt metric: 0.879927
# [200]	valid's binary_logloss: 0.323689	valid's Opt metric: 0.879522
# [300]	valid's binary_logloss: 0.324817	valid's Opt metric: 0.879969
# Early stopping, best iteration is:
# [125]	valid's binary_logloss: 0.323306	valid's Opt metric: 0.879573
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32506	valid's Opt metric: 0.880871
# [200]	valid's binary_logloss: 0.321484	valid's Opt metric: 0.881152
# Early stopping, best iteration is:
# [33]	valid's binary_logloss: 0.371502	valid's Opt metric: 0.881579
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32543	valid's Opt metric: 0.880158
# [200]	valid's binary_logloss: 0.321509	valid's Opt metric: 0.880718
# Early stopping, best iteration is:
# [33]	valid's binary_logloss: 0.371341	valid's Opt metric: 0.88127
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325839	valid's Opt metric: 0.879178
# [200]	valid's binary_logloss: 0.323263	valid's Opt metric: 0.879612
# Early stopping, best iteration is:
# [31]	valid's binary_logloss: 0.37511	valid's Opt metric: 0.880923
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326106	valid's Opt metric: 0.878708
# [200]	valid's binary_logloss: 0.324747	valid's Opt metric: 0.878477
# Early stopping, best iteration is:
# [33]	valid's binary_logloss: 0.370985	valid's Opt metric: 0.880561
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325759	valid's Opt metric: 0.880185
# [200]	valid's binary_logloss: 0.32414	valid's Opt metric: 0.879244
# [300]	valid's binary_logloss: 0.327151	valid's Opt metric: 0.878363
# Early stopping, best iteration is:
# [108]	valid's binary_logloss: 0.324235	valid's Opt metric: 0.880626
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325668	valid's Opt metric: 0.880238
# [200]	valid's binary_logloss: 0.322631	valid's Opt metric: 0.879983
# Early stopping, best iteration is:
# [86]	valid's binary_logloss: 0.32892	valid's Opt metric: 0.880445
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327509	valid's Opt metric: 0.876452
# [200]	valid's binary_logloss: 0.326564	valid's Opt metric: 0.877659
# [300]	valid's binary_logloss: 0.331571	valid's Opt metric: 0.87719
# Early stopping, best iteration is:
# [158]	valid's binary_logloss: 0.324771	valid's Opt metric: 0.878041
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326228	valid's Opt metric: 0.879071
# [200]	valid's binary_logloss: 0.32554	valid's Opt metric: 0.878092
# Early stopping, best iteration is:
# [71]	valid's binary_logloss: 0.334846	valid's Opt metric: 0.879409
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329725	valid's Opt metric: 0.872891
# [200]	valid's binary_logloss: 0.334812	valid's Opt metric: 0.873342
# [300]	valid's binary_logloss: 0.347709	valid's Opt metric: 0.874417
# Early stopping, best iteration is:
# [127]	valid's binary_logloss: 0.327959	valid's Opt metric: 0.873522
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328189	valid's Opt metric: 0.873426
# [200]	valid's binary_logloss: 0.334294	valid's Opt metric: 0.874388
# ...
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.30594	valid's Opt metric: 0.898348
# [200]	valid's binary_logloss: 0.299253	valid's Opt metric: 0.897233
# Early stopping, best iteration is:
# [54]	valid's binary_logloss: 0.331098	valid's Opt metric: 0.8997
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.307435	valid's Opt metric: 0.894072
# [200]	valid's binary_logloss: 0.305128	valid's Opt metric: 0.893515
# Early stopping, best iteration is:
# [67]	valid's binary_logloss: 0.32055	valid's Opt metric: 0.895194
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306676	valid's Opt metric: 0.897957
# [200]	valid's binary_logloss: 0.301412	valid's Opt metric: 0.895881
# Early stopping, best iteration is:
# [68]	valid's binary_logloss: 0.320073	valid's Opt metric: 0.898941
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.308466	valid's Opt metric: 0.899771
# [200]	valid's binary_logloss: 0.298515	valid's Opt metric: 0.899345
# [300]	valid's binary_logloss: 0.298833	valid's Opt metric: 0.898382
# Early stopping, best iteration is:
# [104]	valid's binary_logloss: 0.3073	valid's Opt metric: 0.899823
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305373	valid's Opt metric: 0.899722
# [200]	valid's binary_logloss: 0.298638	valid's Opt metric: 0.898189
# Early stopping, best iteration is:
# [67]	valid's binary_logloss: 0.319663	valid's Opt metric: 0.900525
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.3055	valid's Opt metric: 0.897619
# [200]	valid's binary_logloss: 0.299907	valid's Opt metric: 0.897159
# Early stopping, best iteration is:
# [60]	valid's binary_logloss: 0.323895	valid's Opt metric: 0.899773
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305394	valid's Opt metric: 0.896976
# [200]	valid's binary_logloss: 0.298238	valid's Opt metric: 0.897794
# Early stopping, best iteration is:
# [59]	valid's binary_logloss: 0.325143	valid's Opt metric: 0.898646
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305405	valid's Opt metric: 0.898943
# [200]	valid's binary_logloss: 0.299158	valid's Opt metric: 0.897236
# Early stopping, best iteration is:
# [69]	valid's binary_logloss: 0.318409	valid's Opt metric: 0.899736
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.30617	valid's Opt metric: 0.898733
# [200]	valid's binary_logloss: 0.299511	valid's Opt metric: 0.897301
# Early stopping, best iteration is:
# [78]	valid's binary_logloss: 0.313686	valid's Opt metric: 0.899328
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.307386	valid's Opt metric: 0.896217
# [200]	valid's binary_logloss: 0.301256	valid's Opt metric: 0.895881
# Early stopping, best iteration is:
# [18]	valid's binary_logloss: 0.402382	valid's Opt metric: 0.898961
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306185	valid's Opt metric: 0.897535
# [200]	valid's binary_logloss: 0.301607	valid's Opt metric: 0.896101
# Early stopping, best iteration is:
# [51]	valid's binary_logloss: 0.333328	valid's Opt metric: 0.89931
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.30607	valid's Opt metric: 0.898358
# [200]	valid's binary_logloss: 0.300319	valid's Opt metric: 0.896834
# Early stopping, best iteration is:
# [68]	valid's binary_logloss: 0.319669	valid's Opt metric: 0.899131
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306798	valid's Opt metric: 0.896098
# [200]	valid's binary_logloss: 0.301442	valid's Opt metric: 0.895184
# Early stopping, best iteration is:
# [39]	valid's binary_logloss: 0.350838	valid's Opt metric: 0.89691
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.307061	valid's Opt metric: 0.896768
# [200]	valid's binary_logloss: 0.300213	valid's Opt metric: 0.89625
# Early stopping, best iteration is:
# [13]	valid's binary_logloss: 0.422435	valid's Opt metric: 0.898842
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.30682	valid's Opt metric: 0.900053
# [200]	valid's binary_logloss: 0.298367	valid's Opt metric: 0.899341
# [300]	valid's binary_logloss: 0.299454	valid's Opt metric: 0.897613
# Early stopping, best iteration is:
# [131]	valid's binary_logloss: 0.301071	valid's Opt metric: 0.900078
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306251	valid's Opt metric: 0.897315
# [200]	valid's binary_logloss: 0.30087	valid's Opt metric: 0.896285
# Early stopping, best iteration is:
# [32]	valid's binary_logloss: 0.363829	valid's Opt metric: 0.89848
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.30555	valid's Opt metric: 0.899128
# [200]	valid's binary_logloss: 0.298397	valid's Opt metric: 0.898281
# Early stopping, best iteration is:
# [59]	valid's binary_logloss: 0.326074	valid's Opt metric: 0.899697
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306758	valid's Opt metric: 0.899899
# [200]	valid's binary_logloss: 0.297754	valid's Opt metric: 0.899825
# [300]	valid's binary_logloss: 0.298363	valid's Opt metric: 0.898469
# Early stopping, best iteration is:
# [124]	valid's binary_logloss: 0.301799	valid's Opt metric: 0.900349
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305731	valid's Opt metric: 0.899802
# [200]	valid's binary_logloss: 0.297471	valid's Opt metric: 0.899679
# Early stopping, best iteration is:
# [77]	valid's binary_logloss: 0.314217	valid's Opt metric: 0.900116
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305699	valid's Opt metric: 0.89768
# [200]	valid's binary_logloss: 0.30084	valid's Opt metric: 0.896378
# Early stopping, best iteration is:
# [68]	valid's binary_logloss: 0.318457	valid's Opt metric: 0.898678
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305863	valid's Opt metric: 0.897813
# [200]	valid's binary_logloss: 0.300514	valid's Opt metric: 0.896425
# Early stopping, best iteration is:
# [69]	valid's binary_logloss: 0.318185	valid's Opt metric: 0.899214
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306389	valid's Opt metric: 0.8997
# [200]	valid's binary_logloss: 0.298196	valid's Opt metric: 0.898691
# [300]	valid's binary_logloss: 0.29919	valid's Opt metric: 0.897669
# Early stopping, best iteration is:
# [150]	valid's binary_logloss: 0.29903	valid's Opt metric: 0.899816
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306162	valid's Opt metric: 0.896668
# [200]	valid's binary_logloss: 0.300896	valid's Opt metric: 0.895827
# Early stopping, best iteration is:
# [72]	valid's binary_logloss: 0.316213	valid's Opt metric: 0.897433
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.307349	valid's Opt metric: 0.897683
# [200]	valid's binary_logloss: 0.30021	valid's Opt metric: 0.896534
# Early stopping, best iteration is:
# [79]	valid's binary_logloss: 0.314649	valid's Opt metric: 0.89856
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306577	valid's Opt metric: 0.897163
# [200]	valid's binary_logloss: 0.301352	valid's Opt metric: 0.895765
# Early stopping, best iteration is:
# [62]	valid's binary_logloss: 0.323803	valid's Opt metric: 0.897864
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.308006	valid's Opt metric: 0.895236
# [200]	valid's binary_logloss: 0.30406	valid's Opt metric: 0.893929
# Early stopping, best iteration is:
# [32]	valid's binary_logloss: 0.363621	valid's Opt metric: 0.896394
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.30669	valid's Opt metric: 0.898811
# [200]	valid's binary_logloss: 0.298272	valid's Opt metric: 0.899008
# [300]	valid's binary_logloss: 0.299711	valid's Opt metric: 0.897279
# Early stopping, best iteration is:
# [145]	valid's binary_logloss: 0.299748	valid's Opt metric: 0.899798
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.301163	valid's Opt metric: 0.89566
# Early stopping, best iteration is:
# [49]	valid's binary_logloss: 0.301973	valid's Opt metric: 0.89863
#
# ===== Start working with fold 1 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.29427	valid's Opt metric: 0.89755
# Early stopping, best iteration is:
# [58]	valid's binary_logloss: 0.2963	valid's Opt metric: 0.899065
#
# ===== Start working with fold 2 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.317154	valid's Opt metric: 0.884049
# Early stopping, best iteration is:
# [17]	valid's binary_logloss: 0.354981	valid's Opt metric: 0.88509
#
# ===== Start working with fold 3 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.294351	valid's Opt metric: 0.902545
# [200]	valid's binary_logloss: 0.298498	valid's Opt metric: 0.899354
# Early stopping, best iteration is:
# [101]	valid's binary_logloss: 0.29409	valid's Opt metric: 0.902858
#
# ===== Start working with fold 4 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.310617	valid's Opt metric: 0.890095
# Early stopping, best iteration is:
# [10]	valid's binary_logloss: 0.38513	valid's Opt metric: 0.894498
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Time left 4524.448285579681
# Blending: Optimization starts with equal weights and score 0.890248178772132
# Blending, iter 0: score = 0.8940660886670683, weights = [1. 0.]
# Blending, iter 1: score = 0.8940660886670683, weights = [1. 0.]
# No score update. Terminated
#
# Automl preset training completed in 707.05 seconds.
# Blending: Optimization starts with equal weights and score 0.8975941895010745
# Blending, iter 0: score = 0.8979609406733369, weights = [0.27121955 0.         0.         0.27685452 0.         0.19795506
#  0.25397083]
# Blending, iter 1: score = 0.8979887356998012, weights = [0.13989821 0.         0.         0.2549573  0.         0.3211531
#  0.28399143]
# Blending, iter 2: score = 0.89798990290416, weights = [0.1308189  0.         0.         0.26273626 0.         0.33095178
#  0.275493  ]
# Blending, iter 3: score = 0.89798990290416, weights = [0.1308189  0.         0.         0.26273626 0.         0.33095178
#  0.275493  ]
# No score update. Terminated
# CPU times: user 1d 20min 35s, sys: 16min 42s, total: 1d 37min 18s
# Wall time: 6h 44min 37s

# %%
y_pred = automl.predict(test).data.ravel()

# %%
final_threshold = get_threshold(train.y, y_oof)
final_threshold
# Out:
# 0.34

# %%
print("Final F1     :", custom_f1(train.y, y_oof))
print("Final AUC    :", roc_auc_score(train.y, y_oof))
print("Final LogLoss:", log_loss(train.y, y_oof))
# Out:
# Final F1     : 0.6816942374113798
# Final AUC    : 0.89798990290416
# Final LogLoss: 0.30307432134312423

# %% [markdown]
# # Sub

# %%
# Write predictions to sub
sample_submission['predicted'] = np.where(y_pred>final_threshold, 1, 0).astype('int64')
sample_submission.to_csv('lightautoml_pseudo_sub.csv',index=False)

# Write predictions to stack
sample_submission['predicted'] = y_pred
sample_submission.to_csv('lightautoml_pseudo_sub_probs.csv',index=False)
pd.DataFrame({'id':train_id, 'lightautoml_pseudo_oof':y_oof[range(14123)]}).to_csv('lightautoml_pseudo_oof.csv',index=False)

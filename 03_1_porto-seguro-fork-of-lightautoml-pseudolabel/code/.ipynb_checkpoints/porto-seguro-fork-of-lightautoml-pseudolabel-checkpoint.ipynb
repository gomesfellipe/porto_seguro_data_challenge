# %%
pip install -U lightautoml
# Out:
# Collecting lightautoml
#   Downloading LightAutoML-0.2.16-py3-none-any.whl (262 kB)
#      |████████████████████████████████| 262 kB 544 kB/s
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.0.1)
# Requirement already satisfied: cmaes in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.2)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (from lightautoml) (3.2.4)
# Requirement already satisfied: pandas>=1 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.2.4)
# Collecting poetry-core<2.0.0,>=1.0.0
#   Downloading poetry_core-1.0.6-py2.py3-none-any.whl (424 kB)
#      |████████████████████████████████| 424 kB 3.0 MB/s
# Collecting autowoe>=1.2
#   Downloading AutoWoE-1.2.5-py3-none-any.whl (204 kB)
#      |████████████████████████████████| 204 kB 9.9 MB/s
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.5.2.54)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.5)
# Requirement already satisfied: optuna in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.8.0)
# Requirement already satisfied: transformers>=4 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.6.1)
# Requirement already satisfied: pywavelets in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.1.1)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.18.2)
# Requirement already satisfied: albumentations>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.0.1)
# Collecting importlib-metadata<2.0,>=1.0
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: holidays in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Requirement already satisfied: torch<1.9 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.7.0)
# Collecting log-calls
#   Downloading log_calls-0.3.2.tar.gz (232 kB)
#      |████████████████████████████████| 232 kB 10.1 MB/s
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.6.3)
# Requirement already satisfied: catboost in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.26)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.5.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.61.1)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Collecting lightgbm<3.0,>=2.3
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 10.0 MB/s
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from lightautoml) (5.4.1)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.23.2)
# Collecting json2html
#   Downloading json2html-1.3.0.tar.gz (7.0 kB)
# Collecting efficientnet-pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.19.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (3.0.1)
# Requirement already satisfied: gensim>=4 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.0.1)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from albumentations>=0.4.6->lightautoml) (4.5.2.54)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (2021.1)
# Collecting sphinx
#   Downloading Sphinx-4.2.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 24.9 MB/s
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (0.2.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (3.4.2)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (6.2.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.7/site-packages (from gensim>=4->lightautoml) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata<2.0,>=1.0->lightautoml) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1->lightautoml) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1->lightautoml) (1.15.0)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->lightautoml) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->lightautoml) (8.2.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->lightautoml) (2021.7.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (0.10.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx->lightautoml) (5.0.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.22->lightautoml) (2.1.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch<1.9->lightautoml) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch<1.9->lightautoml) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch<1.9->lightautoml) (0.6)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (20.9)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (3.0.12)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2.25.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.10.3)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.0.45)
# Requirement already satisfied: huggingface-hub==0.0.8 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.0.8)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2021.4.4)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (0.8.4)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (5.1.0)
# Requirement already satisfied: korean-lunar-calendar in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (0.2.1)
# Requirement already satisfied: hijri-converter in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.1.3)
# Requirement already satisfied: convertdate>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.3.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /opt/conda/lib/python3.7/site-packages (from convertdate>=2.3.0->holidays->lightautoml) (0.5.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from jinja2->lightautoml) (2.0.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.4.18)
# Requirement already satisfied: cliff in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (3.8.0)
# Requirement already satisfied: alembic in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.6.5)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (5.0.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.7/site-packages (from sqlalchemy>=1.1.0->optuna->lightautoml) (1.1.0)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.1.4)
# Requirement already satisfied: python-editor>=0.3 in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.0.4)
# Requirement already satisfied: cmd2>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (2.1.2)
# Requirement already satisfied: PrettyTable>=0.7.2 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (2.1.0)
# Requirement already satisfied: stevedore>=2.0.1 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (3.3.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (5.6.0)
# Requirement already satisfied: pyperclip>=1.6 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.2.5)
# Requirement already satisfied: colorama>=0.3.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.4.4)
# Requirement already satisfied: attrs>=16.3.0 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (21.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from plotly->catboost->lightautoml) (7.0.0)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.10.0)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.1.1)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.10.2)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.13.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (1.26.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2021.5.30)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers>=4->lightautoml) (7.1.2)
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: docutils<0.18,>=0.14 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (0.17.1)
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.1.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.6 MB/s
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 7.4 MB/s
# Collecting sphinxcontrib-serializinghtml>=1.1.5
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.4 MB/s
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 50.5 MB/s
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 7.7 MB/s
# Requirement already satisfied: Pygments>=2.0 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.9.0)
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.9.1)
# Collecting imagesize
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (49.6.0.post20210108)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.9 MB/s
# Building wheels for collected packages: efficientnet-pytorch, json2html, log-calls
# done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=fdec6077f595967efec150f1696f2ef34f67de141c2832138bee3d943a402648
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# done
#   Created wheel for json2html: filename=json2html-1.3.0-py3-none-any.whl size=7595 sha256=0ec44c364b6008f8046179c2d45b2313b9af0b4030605b357793c978e5adeb82
#   Stored in directory: /root/.cache/pip/wheels/e5/99/37/e1839a5ad733e0d6abb7e0419fd913e8926ddf96408239ce01
# done
#   Created wheel for log-calls: filename=log_calls-0.3.2-py3-none-any.whl size=51828 sha256=289bf3d5c21c1035d205e6d65ba7bd912443425066f59ccbcebd40467740163a
#   Stored in directory: /root/.cache/pip/wheels/4c/4b/a5/a5643cfdcff002bbaf88cff0e52326db94182507613b53e971
# Successfully built efficientnet-pytorch json2html log-calls
# Installing collected packages: importlib-metadata, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, imagesize, alabaster, sphinx, lightgbm, poetry-core, log-calls, json2html, efficientnet-pytorch, autowoe, lightautoml
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.4.0
#     Uninstalling importlib-metadata-3.4.0:
#       Successfully uninstalled importlib-metadata-3.4.0
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 3.2.1
#     Uninstalling lightgbm-3.2.1:
#       Successfully uninstalled lightgbm-3.2.1
# Successfully installed alabaster-0.7.12 autowoe-1.2.5 efficientnet-pytorch-0.7.1 imagesize-1.2.0 importlib-metadata-1.7.0 json2html-1.3.0 lightautoml-0.2.16 lightgbm-2.3.1 log-calls-0.3.2 poetry-core-1.0.6 snowballstemmer-2.1.0 sphinx-4.2.0 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load dependencies

# %%
import pandas as pd
import numpy as np
import time
from tqdm import tqdm

import torch
from sklearn.metrics import f1_score, roc_auc_score, log_loss

# Imports from our package
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.dataset.roles import DatetimeRole
from lightautoml.tasks import Task

# Everything for graphs
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
train = pd.read_csv('../input/porto-seguro-data-challenge/train.csv', index_col='id')
train_id = train.index
train = train.reset_index(drop=True)
test = pd.read_csv('../input/porto-seguro-data-challenge/test.csv', index_col='id').reset_index(drop=True)
sample_submission = pd.read_csv('../input/porto-seguro-data-challenge/submission_sample.csv')
meta = pd.read_csv('../input/porto-seguro-data-challenge/metadata.csv')

# %%
knn_feat_train = pd.read_csv('../input/porto-seguro-knn-feature-extraction-k-1/knn_feat_train.csv')
knn_feat_test = pd.read_csv('../input/porto-seguro-knn-feature-extraction-k-1/knn_feat_test.csv')

train = pd.concat([train, knn_feat_train], axis=1)
test = pd.concat([test, knn_feat_test], axis=1)

# %%
# Add predictions from other models

train.loc[:,'cat_knn_shap'] = pd.read_csv('../input/porto-seguro-catboost-knn-shap/cat_oof.csv').cat_shap_oof
test.loc[:,'cat_knn_shap'] = pd.read_csv('../input/porto-seguro-catboost-knn-shap/cat_shap_sub_probs.csv').predicted

train.loc[:,'xgb_cat_shap'] = pd.read_csv('../input/porto-seguro-catboost-xgboost-shap-autogluon/autogluon_oof.csv').autogluon_shap_oof
test.loc[:,'xgb_cat_shap'] = pd.read_csv('../input/porto-seguro-catboost-xgboost-shap-autogluon/autogluon_shap_sub_probs.csv').predicted

# %%
train[['cat_knn_shap', 'xgb_cat_shap']].corr()
# Out:
#               cat_knn_shap  xgb_cat_shap
# cat_knn_shap      1.000000      0.977991
# xgb_cat_shap      0.977991      1.000000

# %%
sns.pairplot(train[['cat_knn_shap', 'xgb_cat_shap', 'y']], hue="y");

# %%
# Create new features
for data in [train, test]:
    #data['cat_pseudo_minus_cat_knn_shap'] = data['cat_pseudo'] - data['cat_knn_shap']
    #data['cat_pseudo_mul_cat_knn_shap']   = data['cat_pseudo'] * data['cat_knn_shap']
    #data['cat_pseudo_div_cat_knn_shap']   = data['cat_pseudo'] / data['cat_knn_shap']
    
    #data['autogluon_shap_minus_cat_knn_shap'] = data['autogluon_shap'] - data['cat_knn_shap']
    #data['autogluon_shap_mul_cat_knn_shap']   = data['autogluon_shap'] * data['cat_knn_shap']
    #data['autogluon_shap_div_cat_knn_shap']   = data['autogluon_shap'] / data['cat_knn_shap']
    
    data['cat_knn_shap_minus_xgb_cat_shap'] = data['cat_knn_shap'] - data['xgb_cat_shap']
    data['cat_knn_shap_mul_xgb_cat_shap']   = data['cat_knn_shap'] * data['xgb_cat_shap']
    data['cat_knn_shap_div_xgb_cat_shap']   = data['cat_knn_shap'] / data['xgb_cat_shap']
    
    #data['autogluon_shap_mul_cat_pseudo_mul_cat_knn_shap']   = data['autogluon_shap'] * data['cat_pseudo']* data['cat_knn_shap']

# %%
def get_threshold(y_true, y_pred):
    # Moving threshold
    thresholds = np.arange(0.0, 1.0, 0.01)
    f1_scores = []
    for thresh in thresholds:
        f1_scores.append(
            f1_score(y_true, [1 if m>thresh else 0 for m in y_pred]))
    f1s = np.array(f1_scores)
    return thresholds[f1s.argmax()]
    
    
def custom_f1(y_true, y_pred):
     
    max_f1_threshold =  get_threshold(y_true, y_pred)

    y_pred = np.where(y_pred>max_f1_threshold, 1, 0)
    f1_after = f1_score(y_true, y_pred) 
    
    return f1_after

# %% [markdown]
# # LightAutoML

# %%
# %%time 

N_THREADS = 4 
N_FOLDS = 10
SEED = 5
TIMEOUT = 60 * 60 * 8
TARGET_NAME = 'y'

np.random.seed(SEED)
torch.set_num_threads(N_THREADS)

task = Task('binary', metric = roc_auc_score, greater_is_better=True)

roles = {
    'target': 'y'
}

automl = TabularUtilizedAutoML(task = task, 
                       timeout = TIMEOUT,
                       cpu_limit = N_THREADS,
                       general_params = {'use_algos': [['lgb', 'lgb_tuned', 'cb', 'cb_tunned'], 
                                                       ['linear_l2', 'lgb_tuned']]},
                       reader_params = {'n_jobs': N_THREADS})

y_oof = automl.fit_predict(train, roles = roles).data.ravel()
# Out:
# Current random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# Found reader_params in kwargs, need to combine
# Merged variant for reader_params = {'n_jobs': 4, 'random_state': 42}
# Found general_params in kwargs, need to combine
# Merged variant for general_params = {'use_algos': [['lgb', 'lgb_tuned', 'cb', 'cb_tunned'], ['linear_l2', 'lgb_tuned']], 'return_all_predictions': False}
# Start automl preset with listed constraints:
# - time: 28799.996059417725 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (14123, 76)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 28771.458414316177 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326757	valid's Opt metric: 0.877533
# [200]	valid's binary_logloss: 0.328077	valid's Opt metric: 0.876342
# [300]	valid's binary_logloss: 0.333944	valid's Opt metric: 0.876063
# Early stopping, best iteration is:
# [102]	valid's binary_logloss: 0.326371	valid's Opt metric: 0.878014
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.316352	valid's Opt metric: 0.889312
# [200]	valid's binary_logloss: 0.310138	valid's Opt metric: 0.889103
# Early stopping, best iteration is:
# [55]	valid's binary_logloss: 0.338955	valid's Opt metric: 0.891078
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.298956	valid's Opt metric: 0.901398
# [200]	valid's binary_logloss: 0.290226	valid's Opt metric: 0.901816
# [300]	valid's binary_logloss: 0.292091	valid's Opt metric: 0.901394
# Early stopping, best iteration is:
# [171]	valid's binary_logloss: 0.289855	valid's Opt metric: 0.902662
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.308279	valid's Opt metric: 0.894884
# [200]	valid's binary_logloss: 0.303937	valid's Opt metric: 0.89422
# Early stopping, best iteration is:
# [72]	valid's binary_logloss: 0.318272	valid's Opt metric: 0.896253
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.297804	valid's Opt metric: 0.904565
# [200]	valid's binary_logloss: 0.288446	valid's Opt metric: 0.903513
# [300]	valid's binary_logloss: 0.289191	valid's Opt metric: 0.903631
# Early stopping, best iteration is:
# [109]	valid's binary_logloss: 0.295459	valid's Opt metric: 0.90483
# Lvl_0_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 9672.794553876522 secs
# Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32996	valid's Opt metric: 0.871027
# [200]	valid's binary_logloss: 0.347212	valid's Opt metric: 0.87259
# [300]	valid's binary_logloss: 0.381552	valid's Opt metric: 0.873112
# Early stopping, best iteration is:
# [108]	valid's binary_logloss: 0.329702	valid's Opt metric: 0.871184
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326936	valid's Opt metric: 0.877648
# [200]	valid's binary_logloss: 0.325285	valid's Opt metric: 0.876615
# Early stopping, best iteration is:
# [50]	valid's binary_logloss: 0.351394	valid's Opt metric: 0.878569
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328006	valid's Opt metric: 0.875132
# [200]	valid's binary_logloss: 0.328564	valid's Opt metric: 0.876738
# Early stopping, best iteration is:
# [21]	valid's binary_logloss: 0.397927	valid's Opt metric: 0.877018
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327754	valid's Opt metric: 0.8758
# [200]	valid's binary_logloss: 0.330546	valid's Opt metric: 0.876594
# Early stopping, best iteration is:
# [5]	valid's binary_logloss: 0.465865	valid's Opt metric: 0.876833
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327796	valid's Opt metric: 0.872755
# [200]	valid's binary_logloss: 0.335751	valid's Opt metric: 0.874692
# [300]	valid's binary_logloss: 0.355295	valid's Opt metric: 0.875462
# Early stopping, best iteration is:
# [116]	valid's binary_logloss: 0.327174	valid's Opt metric: 0.873177
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326527	valid's Opt metric: 0.878922
# [200]	valid's binary_logloss: 0.322961	valid's Opt metric: 0.878469
# Early stopping, best iteration is:
# [47]	valid's binary_logloss: 0.353237	valid's Opt metric: 0.879762
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325557	valid's Opt metric: 0.878071
# [200]	valid's binary_logloss: 0.325397	valid's Opt metric: 0.877811
# Early stopping, best iteration is:
# [19]	valid's binary_logloss: 0.404399	valid's Opt metric: 0.879139
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32932	valid's Opt metric: 0.873056
# [200]	valid's binary_logloss: 0.336644	valid's Opt metric: 0.873737
# [300]	valid's binary_logloss: 0.355245	valid's Opt metric: 0.874829
# Early stopping, best iteration is:
# [121]	valid's binary_logloss: 0.328461	valid's Opt metric: 0.872553
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326273	valid's Opt metric: 0.877988
# [200]	valid's binary_logloss: 0.326096	valid's Opt metric: 0.876316
# Early stopping, best iteration is:
# [40]	valid's binary_logloss: 0.360701	valid's Opt metric: 0.878803
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.330266	valid's Opt metric: 0.870659
# [200]	valid's binary_logloss: 0.338251	valid's Opt metric: 0.870922
# Early stopping, best iteration is:
# [48]	valid's binary_logloss: 0.351838	valid's Opt metric: 0.872143
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325728	valid's Opt metric: 0.879995
# [200]	valid's binary_logloss: 0.323239	valid's Opt metric: 0.878361
# [300]	valid's binary_logloss: 0.325988	valid's Opt metric: 0.877251
# Early stopping, best iteration is:
# [101]	valid's binary_logloss: 0.325531	valid's Opt metric: 0.880025
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326409	valid's Opt metric: 0.879907
# [200]	valid's binary_logloss: 0.323182	valid's Opt metric: 0.878766
# Early stopping, best iteration is:
# [93]	valid's binary_logloss: 0.327624	valid's Opt metric: 0.880145
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328274	valid's Opt metric: 0.872692
# [200]	valid's binary_logloss: 0.331347	valid's Opt metric: 0.872625
# Early stopping, best iteration is:
# [26]	valid's binary_logloss: 0.384712	valid's Opt metric: 0.875487
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329545	valid's Opt metric: 0.873144
# [200]	valid's binary_logloss: 0.334803	valid's Opt metric: 0.87444
# Early stopping, best iteration is:
# [34]	valid's binary_logloss: 0.37018	valid's Opt metric: 0.875251
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326237	valid's Opt metric: 0.878966
# [200]	valid's binary_logloss: 0.324885	valid's Opt metric: 0.876745
# Early stopping, best iteration is:
# [7]	valid's binary_logloss: 0.456316	valid's Opt metric: 0.880428
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327177	valid's Opt metric: 0.875623
# [200]	valid's binary_logloss: 0.329341	valid's Opt metric: 0.875386
# Early stopping, best iteration is:
# [33]	valid's binary_logloss: 0.372415	valid's Opt metric: 0.878075
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326497	valid's Opt metric: 0.877433
# [200]	valid's binary_logloss: 0.325443	valid's Opt metric: 0.876365
# Early stopping, best iteration is:
# [10]	valid's binary_logloss: 0.441156	valid's Opt metric: 0.878367
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.3269	valid's Opt metric: 0.876125
# [200]	valid's binary_logloss: 0.329008	valid's Opt metric: 0.874335
# Early stopping, best iteration is:
# [72]	valid's binary_logloss: 0.333734	valid's Opt metric: 0.877189
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328916	valid's Opt metric: 0.872349
# [200]	valid's binary_logloss: 0.334063	valid's Opt metric: 0.873031
# [300]	valid's binary_logloss: 0.346283	valid's Opt metric: 0.87267
# Early stopping, best iteration is:
# [112]	valid's binary_logloss: 0.328383	valid's Opt metric: 0.872311
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328552	valid's Opt metric: 0.873145
# [200]	valid's binary_logloss: 0.341045	valid's Opt metric: 0.873427
# [300]	valid's binary_logloss: 0.36393	valid's Opt metric: 0.874492
# Early stopping, best iteration is:
# [109]	valid's binary_logloss: 0.328118	valid's Opt metric: 0.873129
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327697	valid's Opt metric: 0.877384
# [200]	valid's binary_logloss: 0.325102	valid's Opt metric: 0.876741
# Early stopping, best iteration is:
# [27]	valid's binary_logloss: 0.38671	valid's Opt metric: 0.87914
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32569	valid's Opt metric: 0.879698
# [200]	valid's binary_logloss: 0.323475	valid's Opt metric: 0.878335
# Early stopping, best iteration is:
# [80]	valid's binary_logloss: 0.330714	valid's Opt metric: 0.880091
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32639	valid's Opt metric: 0.878663
# [200]	valid's binary_logloss: 0.323063	valid's Opt metric: 0.878073
# Early stopping, best iteration is:
# [20]	valid's binary_logloss: 0.403531	valid's Opt metric: 0.879388
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326756	valid's Opt metric: 0.876336
# [200]	valid's binary_logloss: 0.328578	valid's Opt metric: 0.874767
# Early stopping, best iteration is:
# [10]	valid's binary_logloss: 0.439021	valid's Opt metric: 0.878456
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327338	valid's Opt metric: 0.877718
# [200]	valid's binary_logloss: 0.32365	valid's Opt metric: 0.877426
# Early stopping, best iteration is:
# [11]	valid's binary_logloss: 0.436297	valid's Opt metric: 0.880151
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.330111	valid's Opt metric: 0.870082
# [200]	valid's binary_logloss: 0.33989	valid's Opt metric: 0.871301
# [300]	valid's binary_logloss: 0.358069	valid's Opt metric: 0.871274
# Early stopping, best iteration is:
# [115]	valid's binary_logloss: 0.328997	valid's Opt metric: 0.871047
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328867	valid's Opt metric: 0.874141
# [200]	valid's binary_logloss: 0.332791	valid's Opt metric: 0.873255
# Early stopping, best iteration is:
# [26]	valid's binary_logloss: 0.386196	valid's Opt metric: 0.875237
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327661	valid's Opt metric: 0.878146
# [200]	valid's binary_logloss: 0.324072	valid's Opt metric: 0.877415
# Early stopping, best iteration is:
# [11]	valid's binary_logloss: 0.436296	valid's Opt metric: 0.879905
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328889	valid's Opt metric: 0.873019
# [200]	valid's binary_logloss: 0.333231	valid's Opt metric: 0.873993
# [300]	valid's binary_logloss: 0.345082	valid's Opt metric: 0.874199
# Early stopping, best iteration is:
# [125]	valid's binary_logloss: 0.327494	valid's Opt metric: 0.873886
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327502	valid's Opt metric: 0.875823
# [200]	valid's binary_logloss: 0.329661	valid's Opt metric: 0.873508
# Early stopping, best iteration is:
# [12]	valid's binary_logloss: 0.430254	valid's Opt metric: 0.8792
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327162	valid's Opt metric: 0.876354
# [200]	valid's binary_logloss: 0.330235	valid's Opt metric: 0.873585
# Early stopping, best iteration is:
# [9]	valid's binary_logloss: 0.444894	valid's Opt metric: 0.87948
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326045	valid's Opt metric: 0.880177
# [200]	valid's binary_logloss: 0.323066	valid's Opt metric: 0.878477
# Early stopping, best iteration is:
# [65]	valid's binary_logloss: 0.338403	valid's Opt metric: 0.8806
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325637	valid's Opt metric: 0.87833
# [200]	valid's binary_logloss: 0.32505	valid's Opt metric: 0.87738
# Early stopping, best iteration is:
# [10]	valid's binary_logloss: 0.439145	valid's Opt metric: 0.880161
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327157	valid's Opt metric: 0.876333
# [200]	valid's binary_logloss: 0.328508	valid's Opt metric: 0.874591
# Early stopping, best iteration is:
# [7]	valid's binary_logloss: 0.454244	valid's Opt metric: 0.880396
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327758	valid's Opt metric: 0.874556
# [200]	valid's binary_logloss: 0.331409	valid's Opt metric: 0.872695
# Early stopping, best iteration is:
# [82]	valid's binary_logloss: 0.330928	valid's Opt metric: 0.875581
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327048	valid's Opt metric: 0.875534
# [200]	valid's binary_logloss: 0.328468	valid's Opt metric: 0.874167
# Early stopping, best iteration is:
# [17]	valid's binary_logloss: 0.411424	valid's Opt metric: 0.878995
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326253	valid's Opt metric: 0.879642
# [200]	valid's binary_logloss: 0.323268	valid's Opt metric: 0.877722
# Early stopping, best iteration is:
# [82]	valid's binary_logloss: 0.330873	valid's Opt metric: 0.880098
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.330141	valid's Opt metric: 0.870718
# [200]	valid's binary_logloss: 0.344998	valid's Opt metric: 0.872628
# [300]	valid's binary_logloss: 0.370819	valid's Opt metric: 0.87334
# Early stopping, best iteration is:
# [110]	valid's binary_logloss: 0.329914	valid's Opt metric: 0.870806
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329764	valid's Opt metric: 0.872791
# [200]	valid's binary_logloss: 0.332406	valid's Opt metric: 0.872059
# Early stopping, best iteration is:
# [25]	valid's binary_logloss: 0.387949	valid's Opt metric: 0.876017
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327189	valid's Opt metric: 0.876343
# [200]	valid's binary_logloss: 0.326897	valid's Opt metric: 0.876484
# Early stopping, best iteration is:
# [17]	valid's binary_logloss: 0.411916	valid's Opt metric: 0.879228
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327774	valid's Opt metric: 0.874771
# [200]	valid's binary_logloss: 0.331393	valid's Opt metric: 0.873454
# Early stopping, best iteration is:
# [73]	valid's binary_logloss: 0.333605	valid's Opt metric: 0.875093
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325601	valid's Opt metric: 0.87808
# [200]	valid's binary_logloss: 0.327319	valid's Opt metric: 0.874585
# Early stopping, best iteration is:
# [10]	valid's binary_logloss: 0.439158	valid's Opt metric: 0.879315
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327895	valid's Opt metric: 0.873201
# [200]	valid's binary_logloss: 0.332251	valid's Opt metric: 0.872999
# Early stopping, best iteration is:
# [38]	valid's binary_logloss: 0.363957	valid's Opt metric: 0.876795
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327454	valid's Opt metric: 0.87755
# [200]	valid's binary_logloss: 0.324688	valid's Opt metric: 0.876341
# Early stopping, best iteration is:
# [11]	valid's binary_logloss: 0.436386	valid's Opt metric: 0.87918
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325496	valid's Opt metric: 0.878306
# [200]	valid's binary_logloss: 0.324106	valid's Opt metric: 0.877863
# Early stopping, best iteration is:
# [10]	valid's binary_logloss: 0.438504	valid's Opt metric: 0.882368
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325573	valid's Opt metric: 0.878115
# [200]	valid's binary_logloss: 0.324758	valid's Opt metric: 0.877445
# Early stopping, best iteration is:
# [6]	valid's binary_logloss: 0.460283	valid's Opt metric: 0.879518
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32544	valid's Opt metric: 0.879434
# [200]	valid's binary_logloss: 0.323892	valid's Opt metric: 0.87763
# Early stopping, best iteration is:
# [31]	valid's binary_logloss: 0.37536	valid's Opt metric: 0.880016
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32696	valid's Opt metric: 0.875956
# [200]	valid's binary_logloss: 0.335826	valid's Opt metric: 0.876579
# [300]	valid's binary_logloss: 0.35615	valid's Opt metric: 0.876504
# Early stopping, best iteration is:
# [108]	valid's binary_logloss: 0.32654	valid's Opt metric: 0.87568
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325339	valid's Opt metric: 0.87949
# [200]	valid's binary_logloss: 0.324683	valid's Opt metric: 0.877202
# Early stopping, best iteration is:
# [7]	valid's binary_logloss: 0.455747	valid's Opt metric: 0.880095
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.330064	valid's Opt metric: 0.87124
# [200]	valid's binary_logloss: 0.342277	valid's Opt metric: 0.871522
# Early stopping, best iteration is:
# [31]	valid's binary_logloss: 0.374695	valid's Opt metric: 0.873067
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325597	valid's Opt metric: 0.878656
# [200]	valid's binary_logloss: 0.323622	valid's Opt metric: 0.878883
# [300]	valid's binary_logloss: 0.326308	valid's Opt metric: 0.877654
# Early stopping, best iteration is:
# [163]	valid's binary_logloss: 0.322748	valid's Opt metric: 0.879106
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326341	valid's Opt metric: 0.878537
# [200]	valid's binary_logloss: 0.324979	valid's Opt metric: 0.87682
# Early stopping, best iteration is:
# [10]	valid's binary_logloss: 0.439624	valid's Opt metric: 0.879214
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327001	valid's Opt metric: 0.879231
# [200]	valid's binary_logloss: 0.323496	valid's Opt metric: 0.87802
# [300]	valid's binary_logloss: 0.326174	valid's Opt metric: 0.876814
# Early stopping, best iteration is:
# [109]	valid's binary_logloss: 0.325417	valid's Opt metric: 0.879445
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327485	valid's Opt metric: 0.875877
# [200]	valid's binary_logloss: 0.332064	valid's Opt metric: 0.872993
# Early stopping, best iteration is:
# [48]	valid's binary_logloss: 0.351295	valid's Opt metric: 0.877335
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328324	valid's Opt metric: 0.873719
# [200]	valid's binary_logloss: 0.336674	valid's Opt metric: 0.87404
# Early stopping, best iteration is:
# [94]	valid's binary_logloss: 0.328493	valid's Opt metric: 0.874458
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326119	valid's Opt metric: 0.878442
# [200]	valid's binary_logloss: 0.323965	valid's Opt metric: 0.877426
# Early stopping, best iteration is:
# [10]	valid's binary_logloss: 0.43965	valid's Opt metric: 0.880277
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326158	valid's Opt metric: 0.878448
# [200]	valid's binary_logloss: 0.324934	valid's Opt metric: 0.876783
# Early stopping, best iteration is:
# [19]	valid's binary_logloss: 0.405294	valid's Opt metric: 0.879683
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327019	valid's Opt metric: 0.876483
# [200]	valid's binary_logloss: 0.327548	valid's Opt metric: 0.874809
# Early stopping, best iteration is:
# [22]	valid's binary_logloss: 0.395884	valid's Opt metric: 0.879465
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327305	valid's Opt metric: 0.875149
# [200]	valid's binary_logloss: 0.332087	valid's Opt metric: 0.873175
# Early stopping, best iteration is:
# [33]	valid's binary_logloss: 0.371087	valid's Opt metric: 0.876472
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325847	valid's Opt metric: 0.877888
# [200]	valid's binary_logloss: 0.325036	valid's Opt metric: 0.876415
# Early stopping, best iteration is:
# [43]	valid's binary_logloss: 0.355991	valid's Opt metric: 0.8797
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325682	valid's Opt metric: 0.87914
# [200]	valid's binary_logloss: 0.323554	valid's Opt metric: 0.878032
# Early stopping, best iteration is:
# [75]	valid's binary_logloss: 0.33241	valid's Opt metric: 0.87952
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327296	valid's Opt metric: 0.878838
# [200]	valid's binary_logloss: 0.32283	valid's Opt metric: 0.878939
# [300]	valid's binary_logloss: 0.324632	valid's Opt metric: 0.878011
# Early stopping, best iteration is:
# [173]	valid's binary_logloss: 0.322407	valid's Opt metric: 0.879038
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326579	valid's Opt metric: 0.879141
# [200]	valid's binary_logloss: 0.324869	valid's Opt metric: 0.87743
# Early stopping, best iteration is:
# [27]	valid's binary_logloss: 0.384666	valid's Opt metric: 0.880497
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326958	valid's Opt metric: 0.876199
# [200]	valid's binary_logloss: 0.327436	valid's Opt metric: 0.875328
# Early stopping, best iteration is:
# [79]	valid's binary_logloss: 0.331395	valid's Opt metric: 0.876913
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.32607	valid's Opt metric: 0.88004
# [200]	valid's binary_logloss: 0.32405	valid's Opt metric: 0.877556
# Early stopping, best iteration is:
# [65]	valid's binary_logloss: 0.338005	valid's Opt metric: 0.880465
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327158	valid's Opt metric: 0.877543
# [200]	valid's binary_logloss: 0.324513	valid's Opt metric: 0.876935
# Early stopping, best iteration is:
# [27]	valid's binary_logloss: 0.385125	valid's Opt metric: 0.878728
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.328858	valid's Opt metric: 0.872097
# [200]	valid's binary_logloss: 0.33598	valid's Opt metric: 0.872323
# Early stopping, best iteration is:
# [12]	valid's binary_logloss: 0.429201	valid's Opt metric: 0.875442
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329972	valid's Opt metric: 0.872119
# [200]	valid's binary_logloss: 0.333538	valid's Opt metric: 0.872183
# Early stopping, best iteration is:
# [63]	valid's binary_logloss: 0.339911	valid's Opt metric: 0.873406
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327096	valid's Opt metric: 0.876532
# [200]	valid's binary_logloss: 0.328505	valid's Opt metric: 0.874734
# Early stopping, best iteration is:
# [62]	valid's binary_logloss: 0.339184	valid's Opt metric: 0.877849
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326658	valid's Opt metric: 0.878882
# [200]	valid's binary_logloss: 0.323629	valid's Opt metric: 0.877829
# Early stopping, best iteration is:
# [82]	valid's binary_logloss: 0.331011	valid's Opt metric: 0.879284
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.325519	valid's Opt metric: 0.879452
# [200]	valid's binary_logloss: 0.324704	valid's Opt metric: 0.877036
# Early stopping, best iteration is:
# [27]	valid's binary_logloss: 0.383447	valid's Opt metric: 0.880808
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326928	valid's Opt metric: 0.877495
# [200]	valid's binary_logloss: 0.325928	valid's Opt metric: 0.876319
# Early stopping, best iteration is:
# [7]	valid's binary_logloss: 0.454407	valid's Opt metric: 0.880467
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326343	valid's Opt metric: 0.878064
# [200]	valid's binary_logloss: 0.326237	valid's Opt metric: 0.876002
# Early stopping, best iteration is:
# [27]	valid's binary_logloss: 0.382893	valid's Opt metric: 0.880345
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326395	valid's Opt metric: 0.878165
# [200]	valid's binary_logloss: 0.325663	valid's Opt metric: 0.875961
# Early stopping, best iteration is:
# [11]	valid's binary_logloss: 0.435002	valid's Opt metric: 0.879746
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327817	valid's Opt metric: 0.875161
# [200]	valid's binary_logloss: 0.32788	valid's Opt metric: 0.87429
# Early stopping, best iteration is:
# [8]	valid's binary_logloss: 0.448587	valid's Opt metric: 0.878098
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.327753	valid's Opt metric: 0.878728
# [200]	valid's binary_logloss: 0.323591	valid's Opt metric: 0.877887
# Early stopping, best iteration is:
# [93]	valid's binary_logloss: 0.329002	valid's Opt metric: 0.878979
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.326589	valid's Opt metric: 0.87611
# [200]	valid's binary_logloss: 0.326068	valid's Opt metric: 0.876885
# [300]	valid's binary_logloss: 0.330751	valid's Opt metric: 0.875271
# Early stopping, best iteration is:
# [130]	valid's binary_logloss: 0.324182	valid's Opt metric: 0.876665
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.33136	valid's Opt metric: 0.872886
# Early stopping, best iteration is:
# [4]	valid's binary_logloss: 0.437892	valid's Opt metric: 0.877827
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.310289	valid's Opt metric: 0.888831
# Early stopping, best iteration is:
# [52]	valid's binary_logloss: 0.31138	valid's Opt metric: 0.890526
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.292976	valid's Opt metric: 0.899341
# Early stopping, best iteration is:
# [34]	valid's binary_logloss: 0.304317	valid's Opt metric: 0.902168
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.303468	valid's Opt metric: 0.893499
# Early stopping, best iteration is:
# [29]	valid's binary_logloss: 0.316996	valid's Opt metric: 0.897674
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.288922	valid's Opt metric: 0.903915
# Early stopping, best iteration is:
# [32]	valid's binary_logloss: 0.305105	valid's Opt metric: 0.906063
# Lvl_0_Pipe_0_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_0_Mod_2_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_2_CatBoost =====
#
# 0:	learn: 0.6587025	test: 0.6590502	best: 0.6590502 (0)	total: 71.7ms	remaining: 5m 58s
# 100:	learn: 0.2830009	test: 0.3221705	best: 0.3221661 (94)	total: 856ms	remaining: 41.5s
# 200:	learn: 0.2677194	test: 0.3227448	best: 0.3214019 (150)	total: 1.61s	remaining: 38.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.3214018938
# bestIteration = 150
#
# Shrink model to first 151 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_2_CatBoost =====
#
# 0:	learn: 0.6612033	test: 0.6618783	best: 0.6618783 (0)	total: 8.39ms	remaining: 42s
# 100:	learn: 0.2873691	test: 0.3055667	best: 0.3055667 (100)	total: 761ms	remaining: 36.9s
# 200:	learn: 0.2717649	test: 0.3037270	best: 0.3034678 (151)	total: 1.5s	remaining: 35.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.3034678223
# bestIteration = 151
#
# Shrink model to first 152 iterations.
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_2_CatBoost =====
#
# 0:	learn: 0.6595231	test: 0.6593362	best: 0.6593362 (0)	total: 8.31ms	remaining: 41.5s
# 100:	learn: 0.2911710	test: 0.2900812	best: 0.2900812 (100)	total: 767ms	remaining: 37.2s
# 200:	learn: 0.2756424	test: 0.2873622	best: 0.2873622 (200)	total: 1.51s	remaining: 36s
# 300:	learn: 0.2608680	test: 0.2874393	best: 0.2870482 (245)	total: 2.25s	remaining: 35.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2870481994
# bestIteration = 245
#
# Shrink model to first 246 iterations.
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_2_CatBoost =====
#
# 0:	learn: 0.6640544	test: 0.6643873	best: 0.6643873 (0)	total: 7.4ms	remaining: 37s
# 100:	learn: 0.2889332	test: 0.2992049	best: 0.2990977 (88)	total: 758ms	remaining: 36.8s
# 200:	learn: 0.2732392	test: 0.2993046	best: 0.2986693 (149)	total: 1.51s	remaining: 36.1s
# 300:	learn: 0.2582472	test: 0.2995739	best: 0.2984720 (232)	total: 2.26s	remaining: 35.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2984719727
# bestIteration = 232
#
# Shrink model to first 233 iterations.
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_2_CatBoost =====
#
# 0:	learn: 0.6640410	test: 0.6631538	best: 0.6631538 (0)	total: 7.52ms	remaining: 37.6s
# 100:	learn: 0.2932266	test: 0.2870809	best: 0.2870344 (99)	total: 800ms	remaining: 38.8s
# 200:	learn: 0.2775337	test: 0.2846373	best: 0.2846373 (200)	total: 1.54s	remaining: 36.8s
# 300:	learn: 0.2618617	test: 0.2848864	best: 0.2844944 (284)	total: 2.34s	remaining: 36.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2844943803
# bestIteration = 284
#
# Shrink model to first 285 iterations.
# Lvl_0_Pipe_0_Mod_2_CatBoost fitting and predicting completed
# Time left 28428.24507713318
# Layer 1 training completed.
#
#
# Layer 2 ...
# Train process start. Time left 28428.22351717949 secs
# Start fitting Lvl_1_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.8735830707589374
# Linear model: C = 5e-05 score = 0.8788454506554635
# Linear model: C = 0.0001 score = 0.8803275372466643
# Linear model: C = 0.0005 score = 0.8798125024312444
# Linear model: C = 0.001 score = 0.878553701326487
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.8750402614073987
# Linear model: C = 5e-05 score = 0.8855580192165559
# Linear model: C = 0.0001 score = 0.8891570389388104
# Linear model: C = 0.0005 score = 0.8927972925662271
# Linear model: C = 0.001 score = 0.8927194927451667
# Linear model: C = 0.005 score = 0.8907472672812854
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.8854203135332789
# Linear model: C = 5e-05 score = 0.8966017038160812
# Linear model: C = 0.0001 score = 0.899630450849963
# Linear model: C = 0.0005 score = 0.9018314077877619
# Linear model: C = 0.001 score = 0.901696036099117
# Linear model: C = 0.005 score = 0.9010051736881004
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.8792750509814911
# Linear model: C = 5e-05 score = 0.8888774731860708
# Linear model: C = 0.0001 score = 0.8923099674652469
# Linear model: C = 0.0005 score = 0.8964289606002585
# Linear model: C = 0.001 score = 0.8969558990644312
# Linear model: C = 0.005 score = 0.896815018913744
# Linear model: C = 0.01 score = 0.8965099083111505
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.8934385653574931
# Linear model: C = 5e-05 score = 0.9020190227120597
# Linear model: C = 0.0001 score = 0.9042520898519592
# Linear model: C = 0.0005 score = 0.9062376437989383
# Linear model: C = 0.001 score = 0.9061387941904451
# Linear model: C = 0.005 score = 0.9058274568408599
# Lvl_1_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 28422.864055871964
# Optuna may run 25480.024154853814 secs
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.329819	valid's Opt metric: 0.870158
# [200]	valid's binary_logloss: 0.346438	valid's Opt metric: 0.872612
# [300]	valid's binary_logloss: 0.377139	valid's Opt metric: 0.875245
# Early stopping, best iteration is:
# [106]	valid's binary_logloss: 0.329568	valid's Opt metric: 0.870145
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ...
# [300]	valid's binary_logloss: 0.297866	valid's Opt metric: 0.899038
# Early stopping, best iteration is:
# [196]	valid's binary_logloss: 0.298052	valid's Opt metric: 0.899977
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305266	valid's Opt metric: 0.89911
# [200]	valid's binary_logloss: 0.29762	valid's Opt metric: 0.898397
# Early stopping, best iteration is:
# [66]	valid's binary_logloss: 0.320453	valid's Opt metric: 0.899934
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305706	valid's Opt metric: 0.898666
# [200]	valid's binary_logloss: 0.299168	valid's Opt metric: 0.896947
# Early stopping, best iteration is:
# [37]	valid's binary_logloss: 0.354879	valid's Opt metric: 0.899691
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.307155	valid's Opt metric: 0.899499
# [200]	valid's binary_logloss: 0.297964	valid's Opt metric: 0.899108
# [300]	valid's binary_logloss: 0.298071	valid's Opt metric: 0.898334
# Early stopping, best iteration is:
# [103]	valid's binary_logloss: 0.306327	valid's Opt metric: 0.899746
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306021	valid's Opt metric: 0.899318
# [200]	valid's binary_logloss: 0.298362	valid's Opt metric: 0.898332
# Early stopping, best iteration is:
# [95]	valid's binary_logloss: 0.307259	valid's Opt metric: 0.899551
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305966	valid's Opt metric: 0.8969
# [200]	valid's binary_logloss: 0.299568	valid's Opt metric: 0.89651
# Early stopping, best iteration is:
# [36]	valid's binary_logloss: 0.356544	valid's Opt metric: 0.898762
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306317	valid's Opt metric: 0.897357
# [200]	valid's binary_logloss: 0.299631	valid's Opt metric: 0.896648
# Early stopping, best iteration is:
# [31]	valid's binary_logloss: 0.366854	valid's Opt metric: 0.898057
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305433	valid's Opt metric: 0.896315
# [200]	valid's binary_logloss: 0.300062	valid's Opt metric: 0.895656
# Early stopping, best iteration is:
# [65]	valid's binary_logloss: 0.319577	valid's Opt metric: 0.898045
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306694	valid's Opt metric: 0.894228
# [200]	valid's binary_logloss: 0.305665	valid's Opt metric: 0.89445
# [300]	valid's binary_logloss: 0.315657	valid's Opt metric: 0.895705
# Early stopping, best iteration is:
# [152]	valid's binary_logloss: 0.302399	valid's Opt metric: 0.894102
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305941	valid's Opt metric: 0.898013
# [200]	valid's binary_logloss: 0.299483	valid's Opt metric: 0.896819
# Early stopping, best iteration is:
# [36]	valid's binary_logloss: 0.356895	valid's Opt metric: 0.898992
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306587	valid's Opt metric: 0.898885
# [200]	valid's binary_logloss: 0.299786	valid's Opt metric: 0.897306
# Early stopping, best iteration is:
# [36]	valid's binary_logloss: 0.358145	valid's Opt metric: 0.899355
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.30484	valid's Opt metric: 0.898483
# [200]	valid's binary_logloss: 0.298736	valid's Opt metric: 0.897784
# Early stopping, best iteration is:
# [76]	valid's binary_logloss: 0.313455	valid's Opt metric: 0.899046
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305986	valid's Opt metric: 0.900243
# [200]	valid's binary_logloss: 0.297539	valid's Opt metric: 0.899676
# [300]	valid's binary_logloss: 0.297697	valid's Opt metric: 0.899061
# Early stopping, best iteration is:
# [175]	valid's binary_logloss: 0.29742	valid's Opt metric: 0.90058
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.30646	valid's Opt metric: 0.899619
# [200]	valid's binary_logloss: 0.297431	valid's Opt metric: 0.899281
# Early stopping, best iteration is:
# [16]	valid's binary_logloss: 0.411064	valid's Opt metric: 0.900832
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.3057	valid's Opt metric: 0.900625
# [200]	valid's binary_logloss: 0.296551	valid's Opt metric: 0.899585
# Early stopping, best iteration is:
# [26]	valid's binary_logloss: 0.380307	valid's Opt metric: 0.901276
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306615	valid's Opt metric: 0.899484
# [200]	valid's binary_logloss: 0.297358	valid's Opt metric: 0.899271
# Early stopping, best iteration is:
# [19]	valid's binary_logloss: 0.400774	valid's Opt metric: 0.90055
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305974	valid's Opt metric: 0.898053
# [200]	valid's binary_logloss: 0.300015	valid's Opt metric: 0.895979
# Early stopping, best iteration is:
# [12]	valid's binary_logloss: 0.425644	valid's Opt metric: 0.899763
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306139	valid's Opt metric: 0.899781
# [200]	valid's binary_logloss: 0.298066	valid's Opt metric: 0.898495
# Early stopping, best iteration is:
# [18]	valid's binary_logloss: 0.403304	valid's Opt metric: 0.901178
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306305	valid's Opt metric: 0.896734
# [200]	valid's binary_logloss: 0.300946	valid's Opt metric: 0.89605
# Early stopping, best iteration is:
# [35]	valid's binary_logloss: 0.357635	valid's Opt metric: 0.898158
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306269	valid's Opt metric: 0.899591
# [200]	valid's binary_logloss: 0.297695	valid's Opt metric: 0.898898
# Early stopping, best iteration is:
# [35]	valid's binary_logloss: 0.359135	valid's Opt metric: 0.901172
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305992	valid's Opt metric: 0.898717
# [200]	valid's binary_logloss: 0.297385	valid's Opt metric: 0.898475
# Early stopping, best iteration is:
# [77]	valid's binary_logloss: 0.314212	valid's Opt metric: 0.899385
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306612	valid's Opt metric: 0.899242
# [200]	valid's binary_logloss: 0.297668	valid's Opt metric: 0.898667
# Early stopping, best iteration is:
# [19]	valid's binary_logloss: 0.401326	valid's Opt metric: 0.901156
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305848	valid's Opt metric: 0.898277
# [200]	valid's binary_logloss: 0.2975	valid's Opt metric: 0.897921
# Early stopping, best iteration is:
# [57]	valid's binary_logloss: 0.327751	valid's Opt metric: 0.899236
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306483	valid's Opt metric: 0.898555
# [200]	valid's binary_logloss: 0.30005	valid's Opt metric: 0.896481
# Early stopping, best iteration is:
# [46]	valid's binary_logloss: 0.34218	valid's Opt metric: 0.900012
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.30762	valid's Opt metric: 0.897109
# [200]	valid's binary_logloss: 0.301272	valid's Opt metric: 0.895749
# Early stopping, best iteration is:
# [52]	valid's binary_logloss: 0.334087	valid's Opt metric: 0.898324
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.306453	valid's Opt metric: 0.89856
# [200]	valid's binary_logloss: 0.297627	valid's Opt metric: 0.898715
# Early stopping, best iteration is:
# [16]	valid's binary_logloss: 0.410172	valid's Opt metric: 0.899676
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.305034	valid's Opt metric: 0.898845
# [200]	valid's binary_logloss: 0.298004	valid's Opt metric: 0.897493
# Early stopping, best iteration is:
# [14]	valid's binary_logloss: 0.416735	valid's Opt metric: 0.902423
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.307033	valid's Opt metric: 0.89677
# [200]	valid's binary_logloss: 0.301482	valid's Opt metric: 0.895502
# Early stopping, best iteration is:
# [36]	valid's binary_logloss: 0.356083	valid's Opt metric: 0.897902
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.297662	valid's Opt metric: 0.897536
# Early stopping, best iteration is:
# [16]	valid's binary_logloss: 0.346953	valid's Opt metric: 0.901388
#
# ===== Start working with fold 1 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.294388	valid's Opt metric: 0.897132
# Early stopping, best iteration is:
# [67]	valid's binary_logloss: 0.293923	valid's Opt metric: 0.898766
#
# ===== Start working with fold 2 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.321772	valid's Opt metric: 0.881523
# Early stopping, best iteration is:
# [53]	valid's binary_logloss: 0.319844	valid's Opt metric: 0.8827
#
# ===== Start working with fold 3 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.296223	valid's Opt metric: 0.89944
# Early stopping, best iteration is:
# [74]	valid's binary_logloss: 0.296083	valid's Opt metric: 0.900778
#
# ===== Start working with fold 4 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.309738	valid's Opt metric: 0.888906
# Early stopping, best iteration is:
# [22]	valid's binary_logloss: 0.335607	valid's Opt metric: 0.89414
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Time left 4440.304864645004
# Blending: Optimization starts with equal weights and score 0.891137432866296
# Blending, iter 0: score = 0.8936053386371099, weights = [1. 0.]
# Blending, iter 1: score = 0.8936053386371099, weights = [1. 0.]
# No score update. Terminated
#
# Automl preset training completed in 700.92 seconds.
# Blending: Optimization starts with equal weights and score 0.8966370041132281
# Blending, iter 0: score = 0.8971059556991476, weights = [0.31881618 0.12607822 0.         0.         0.17313959 0.
#  0.38196602]
# Blending, iter 1: score = 0.8971270587539548, weights = [0.42277077 0.05408399 0.         0.         0.15318297 0.
#  0.3699623 ]
# Blending, iter 2: score = 0.8971270587539549, weights = [0.42547774 0.05383036 0.         0.         0.15246458 0.
#  0.3682273 ]
# Blending, iter 3: score = 0.8971270587539549, weights = [0.42547774 0.05383036 0.         0.         0.15246458 0.
#  0.3682273 ]
# No score update. Terminated
# CPU times: user 1d 33min 57s, sys: 16min 47s, total: 1d 50min 44s
# Wall time: 6h 46min 1s

# %%
y_pred = automl.predict(test).data.ravel()

# %%
final_threshold = get_threshold(train.y, y_oof)
final_threshold
# Out:
# 0.31

# %%
print("Final F1     :", custom_f1(train.y, y_oof))
print("Final AUC    :", roc_auc_score(train.y, y_oof))
print("Final LogLoss:", log_loss(train.y, y_oof))
# Out:
# Final F1     : 0.6842664776754076
# Final AUC    : 0.8971281481446897
# Final LogLoss: 0.30458006619369676

# %% [markdown]
# # Sub

# %%
# Write predictions to sub
sample_submission['predicted'] = np.where(y_pred>final_threshold, 1, 0).astype('int64')
sample_submission.to_csv('lightautoml_pseudo_sub.csv',index=False)

# Write predictions to stack
sample_submission['predicted'] = y_pred
sample_submission.to_csv('lightautoml_pseudo_sub_probs.csv',index=False)
pd.DataFrame({'id':train_id, 'lightautoml_pseudo_oof':y_oof}).to_csv('lightautoml_pseudo_oof.csv',index=False)
